# %%
import numpy as np
import pandas as pd

from datetime import datetime

from matplotlib import pyplot as plt
import seaborn as sns

# %%
apteka_list =  [
                #{'name':'vita', 'prefix':2000000},
                {'name':'rigla', 'prefix':1000000},
                {'name':'apteka36','prefix':3000000},
                {'name':'asna','prefix':4000000},
                {'name':'eapteka','prefix':5000000},
                {'name':'evalar','prefix':6000000}]

# %%
def make_combined_category():
    '''
    Функция Собирает все файлы категорий в один и сохраняет как csv файл
    '''
    
    df_full = pd.DataFrame()
    # Цикл по списку аптек
    for apteka_dict in apteka_list:
        apteka = apteka_dict['name']
        prefix = apteka_dict['prefix']
        
        # Сформируем имена файлов
        file_name_categories = apteka+'_categories.csv'
        df_categories = pd.read_csv(file_name_categories)
        df_categories['apteka_name'] = apteka
        df_categories['prefix'] = prefix
        df_categories['new_category_id'] = df_categories['category_id'] + prefix 
        
        print('Загрузил: ',file_name_categories)

        df_full = df_full.append(df_categories)
            
    return df_full

# %%
def make_combined_product_categories():
    '''
    Функция Собирает все файлы категорий в один и сохраняет как csv файл
    '''
    
    df_full = pd.DataFrame()
    # Цикл по списку аптек
    for apteka_dict in apteka_list:
        apteka = apteka_dict['name']
        prefix = apteka_dict['prefix']
        
        # Сформируем имена файлов
        file_name = apteka+'_product_categories.csv'
        df = pd.read_csv(file_name)
        
        df['apteka_name'] = apteka
        df['prefix'] = prefix
        df['new_product_id'] = df['product_id'] + prefix 
        df['new_category_id'] = df['category_id'] + prefix 
        
        print('Загрузил: ',file_name)

        df_full = df_full.append(df)
            
    return df_full

# %%
def make_combined_product():
    '''
    Функция Собирает все файлы категорий в один и сохраняет как csv файл
    '''
    
    df_full = pd.DataFrame()
    # Цикл по списку аптек
    for apteka_dict in apteka_list:
        apteka = apteka_dict['name']
        prefix = apteka_dict['prefix']
        
        # Сформируем имена файлов
        file_name = apteka+'_products.csv'
        df = pd.read_csv(file_name)
        
        df['apteka_name'] = apteka
        df['prefix'] = prefix
        df['new_product_id'] = df['product_id'] + prefix 
        
        print('Загрузил: ',file_name)

        df_full = df_full.append(df)
            
    return df_full

# %%
def make_combined_product_infos():
    '''
    Функция Собирает все файлы категорий в один и сохраняет как csv файл
    '''
    
    df_full = pd.DataFrame()
    # Цикл по списку аптек
    for apteka_dict in apteka_list:
        apteka = apteka_dict['name']
        prefix = apteka_dict['prefix']
        
        # Сформируем имена файлов
        file_name = apteka+'_product_infos.csv'
        df = pd.read_csv(file_name)
        
        df['apteka_name'] = apteka
        df['prefix'] = prefix
        df['new_product_id'] = df['product_id'] + prefix 
        
        print('Загрузил: ',file_name)

        df_full = df_full.append(df)
            
    return df_full

# %%
def make_combined_purchases(filter_list):
    '''
    Функция Собирает все файлы категорий в один и сохраняет как csv файл
    '''
    
    df_full = pd.DataFrame()
    # Цикл по списку аптек
    for apteka_dict in apteka_list:
        apteka = apteka_dict['name']
        prefix = apteka_dict['prefix']
        
        # Сформируем имена файлов
        file_name = apteka+'_purchases.csv'
        df = pd.read_csv(file_name)
        
        df['apteka_name'] = apteka
        df['prefix'] = prefix
        df['new_product_id'] = df['product_id'] + prefix 
        
        df = df[df.new_product_id.isin(filter_list)]
        
        print('Загрузил: ',file_name)

        df_full = df_full.append(df)
        del df
            
    return df_full

# %% [markdown]
# #### сформируем итоговую таблицу с категориями

# %%
df_full_categories = make_combined_category()
df_full_categories.reset_index(drop = True)
# Out:
# Загрузил:  rigla_categories.csv
# Загрузил:  apteka36_categories.csv
# Загрузил:  asna_categories.csv
# Загрузил:  eapteka_categories.csv
# Загрузил:  evalar_categories.csv
#        category_id                 Name apteka_name   prefix  new_category_id
# 0             2111                    -       rigla  1000000          1002111
# 1             1462                   Rx       rigla  1000000          1001462
# 2              277              Гигиена       rigla  1000000          1000277
# 3             2188              Детство       rigla  1000000          1002188
# 4              196       Красота и уход       rigla  1000000          1000196
# ...            ...                  ...         ...      ...              ...
# 10149         1235  Сердечно-сосудистые      evalar  6000000          6001235
# 10150         1241        Снижение веса      evalar  6000000          6001241
# 10151         1236             Урология      evalar  6000000          6001236
# 10152         1383               активн      evalar  6000000          6001383
# 10153         1343             неактивн      evalar  6000000          6001343
#
# [10154 rows x 5 columns]

# %%
# C этой аптекой что то не то, посчитаем всего уникальных категорий у этой аптеки

rigla_cat_full = df_full_categories[df_full_categories.apteka_name == 'rigla']['new_category_id'].value_counts().index
len(rigla_cat_full)
# Out:
# 2379

# %%
df_full_categories.to_csv('categories_full.csv')
del df_full_categories

# %% [markdown]
# #### Загрузим обработанные категории

# %%
df_category_full = pd.read_csv('category_full_select3.csv', sep =';' , encoding='cp1251')

# %%
df_category_full
# Out:
#        Unnamed: 0  category_id                 Name apteka_name   prefix  \
# 0               0         2111                    -       rigla  1000000
# 1               1         1462                   Rx       rigla  1000000
# 2               2          277              Гигиена       rigla  1000000
# 3               3         2188              Детство       rigla  1000000
# 4               4          196       Красота и уход       rigla  1000000
# ...           ...          ...                  ...         ...      ...
# 10149        1392         1235  Сердечно-сосудистые      evalar  6000000
# 10150        1393         1241        Снижение веса      evalar  6000000
# 10151        1394         1236             Урология      evalar  6000000
# 10152        1395         1383               активн      evalar  6000000
# 10153        1396         1343             неактивн      evalar  6000000
#
#        new_category_id  select
# 0              1002111     NaN
# 1              1001462     NaN
# 2              1000277     NaN
# 3              1002188     NaN
# 4              1000196     NaN
# ...                ...     ...
# 10149          6001235     NaN
# 10150          6001241     NaN
# 10151          6001236     NaN
# 10152          6001383     NaN
# 10153          6001343     NaN
#
# [10154 rows x 7 columns]

# %%
df_category_selected = df_category_full[df_category_full.select == 1]
del df_category_full

df_category_selected
# Out:
#       Unnamed: 0  category_id                           Name apteka_name  \
# 178          178            7                Витамины и БАДы       rigla
# 179          179          114      Гомеопатические препараты       rigla
# 623          623         2027  Биологически активные добавки       rigla
# 1714        1714        10741  Биологически активные добавки       rigla
# 2003        2003        12144                Витамины и БАДы       rigla
# 3346         967         1313                Витамины и БАДы    apteka36
# 3433        1054           51                Витамины и БАДы    apteka36
# 3944           0          119                            БАД        asna
# 3946           2         2983                     Гомеопатия        asna
# 4973           1         1960                 Витамины и БАД     eapteka
# 5338         366          262                     Гомеопатия     eapteka
# 6118        1146         4279                 Витамины и БАД     eapteka
# 6140        1168         4817                 Витамины и БАД     eapteka
# 6153        1181         4944                     Гомеопатия     eapteka
# 6868        1896         3218                 Витамины и БАД     eapteka
# 6931        1959         3082                     Гомеопатия     eapteka
# 7979        3007         4274                 Витамины и БАД     eapteka
# 8057        3085         4511                 Витамины и БАД     eapteka
# 8070        3098         4671                     Гомеопатия     eapteka
# 9394         637         1079                     БАДы (772)      evalar
# 9395         638         1292                    БАДы (bady)      evalar
# 9452         695         1191                        Омега-3      evalar
# 9453         696         1271              Омега-3 (1023353)      evalar
# 9480         723          513                           БАДы      evalar
# 9483         726          643       Гомеопатические средства      evalar
#
#        prefix  new_category_id  select
# 178   1000000          1000007     1.0
# 179   1000000          1000114     1.0
# 623   1000000          1002027     1.0
# 1714  1000000          1010741     1.0
# 2003  1000000          1012144     1.0
# 3346  3000000          3001313     1.0
# 3433  3000000          3000051     1.0
# 3944  4000000          4000119     1.0
# 3946  4000000          4002983     1.0
# 4973  5000000          5001960     1.0
# 5338  5000000          5000262     1.0
# 6118  5000000          5004279     1.0
# 6140  5000000          5004817     1.0
# 6153  5000000          5004944     1.0
# 6868  5000000          5003218     1.0
# 6931  5000000          5003082     1.0
# 7979  5000000          5004274     1.0
# 8057  5000000          5004511     1.0
# 8070  5000000          5004671     1.0
# 9394  6000000          6001079     1.0
# 9395  6000000          6001292     1.0
# 9452  6000000          6001191     1.0
# 9453  6000000          6001271     1.0
# 9480  6000000          6000513     1.0
# 9483  6000000          6000643     1.0

# %%
# Список всех новых id отобранных категорий

new_category_id_selected_list = df_category_selected['new_category_id'].to_list()
new_category_id_selected_list
# Out:
# [1000007,
#  1000114,
#  1002027,
#  1010741,
#  1012144,
#  3001313,
#  3000051,
#  4000119,
#  4002983,
#  5001960,
#  5000262,
#  5004279,
#  5004817,
#  5004944,
#  5003218,
#  5003082,
#  5004274,
#  5004511,
#  5004671,
#  6001079,
#  6001292,
#  6001191,
#  6001271,
#  6000513,
#  6000643]

# %% [markdown]
# #### сформируем итоговую таблицу с продукт - категория

# %%
df_procuct_categories_full = make_combined_product_categories().reset_index(drop = True)
df_procuct_categories_full
# Out:
# Загрузил:  rigla_product_categories.csv
# Загрузил:  apteka36_product_categories.csv
# Загрузил:  asna_product_categories.csv
# Загрузил:  eapteka_product_categories.csv
# Загрузил:  evalar_product_categories.csv
#         product_id  category_id apteka_name   prefix  new_product_id  \
# 0               26         3818       rigla  1000000         1000026
# 1               36         3818       rigla  1000000         1000036
# 2               97         3818       rigla  1000000         1000097
# 3              128         3818       rigla  1000000         1000128
# 4              144         3818       rigla  1000000         1000144
# ...            ...          ...         ...      ...             ...
# 997542       67720          290      evalar  6000000         6067720
# 997543        2317          291      evalar  6000000         6002317
# 997544        2318          291      evalar  6000000         6002318
# 997545        4110          291      evalar  6000000         6004110
# 997546        4113          291      evalar  6000000         6004113
#
#         new_category_id
# 0               1003818
# 1               1003818
# 2               1003818
# 3               1003818
# 4               1003818
# ...                 ...
# 997542          6000290
# 997543          6000291
# 997544          6000291
# 997545          6000291
# 997546          6000291
#
# [997547 rows x 6 columns]

# %%
# C этой аптекой что то не то, посчитаем всего уникальных категорий у этой аптеки

rigla_prod_cat_full = df_procuct_categories_full[df_procuct_categories_full.apteka_name == 'rigla']['new_category_id'].value_counts().index
len(rigla_prod_cat_full)
# Out:
# 726

# %%
# Посчитаем пересечение множеств категорий из первого файла и категорий из второго
# Вообщем с файлом продукт_категория что то не то, 

len(set(rigla_cat_full) & set(rigla_prod_cat_full))
# Out:
# 725

# %% [markdown]
# <div style="background: #eeeeff; padding: 5px; border: 1px solid blue; border-radius: 7px;">
# <font color='black'>
#     <b><u>КОММЕНТАРИЙ </u></b>
# <font color='black'>
# <br>
#     Вообщем с файлом продукт_категория что то не то, для аптеки rigla точно, в файле категорий 2 слишним тыс категорий, в файле продукт_категория всего 726 категорий. Отобранных тобой катогорий с БАДами в продукт_категория нет. поэтому по rigla не возможно получить йдишники продуктов, ну и соответвенно заказов тоже не будет. ХОтя все файлы грузятся.
#
#
# <br />

# %%
# Оставим только строки для айдишников из списка отобранных

df_procuct_categories_selected = df_procuct_categories_full[df_procuct_categories_full.new_category_id.isin(new_category_id_selected_list)]
del df_procuct_categories_full

df_procuct_categories_selected
# Out:
#         product_id  category_id apteka_name   prefix  new_product_id  \
# 174316       12575           51    apteka36  3000000         3012575
# 174317       12839           51    apteka36  3000000         3012839
# 174318       12997           51    apteka36  3000000         3012997
# 174319       13355           51    apteka36  3000000         3013355
# 174320       13906           51    apteka36  3000000         3013906
# ...            ...          ...         ...      ...             ...
# 994537       72844         1292      evalar  6000000         6072844
# 994538       73205         1292      evalar  6000000         6073205
# 996993       20486         1292      evalar  6000000         6020486
# 996994       20487         1292      evalar  6000000         6020487
# 996995       20491         1292      evalar  6000000         6020491
#
#         new_category_id
# 174316          3000051
# 174317          3000051
# 174318          3000051
# 174319          3000051
# 174320          3000051
# ...                 ...
# 994537          6001292
# 994538          6001292
# 996993          6001292
# 996994          6001292
# 996995          6001292
#
# [2173 rows x 6 columns]

# %%
# Список всех новых id товаров по отобранным категориям

new_product_id_selected_list = df_procuct_categories_selected['new_product_id'].to_list()

# %%
df_procuct_full = make_combined_product().reset_index(drop = True)
df_procuct_full
# Out:
# Загрузил:  rigla_products.csv
# Загрузил:  apteka36_products.csv
# Загрузил:  asna_products.csv
# Загрузил:  eapteka_products.csv
# Загрузил:  evalar_products.csv
#          product_id  group_id  price  old_price  manufacturer_id  \
# 0             11076         1  330.0        NaN            127.0
# 1             11075         2   33.5        NaN             91.0
# 2             11077         3   50.0        NaN             91.0
# 3             11078         4  191.5        NaN            127.0
# 4              1586         5   92.0        NaN            127.0
# ...             ...       ...    ...        ...              ...
# 1708433       73339     73340  234.0        NaN             91.0
# 1708434       73340     73341  322.0      379.0             20.0
# 1708435       73341     73342  180.0      400.0            533.0
# 1708436       73342     73343  288.0      339.0             20.0
# 1708437       73343     73344  421.0      495.0             20.0
#
#          is_product_unknown  external_system_id  is_available  brand_id  \
# 0                         0                  12          True         1
# 1                         0                  12          True         1
# 2                         0                  12          True         1
# 3                         0                  12          True         1
# 4                         0                  12          True         1
# ...                     ...                 ...           ...       ...
# 1708433                   0                   1         False         1
# 1708434                   0                   1          True         1
# 1708435                   0                   1         False         1
# 1708436                   0                   1         False         1
# 1708437                   0                   1          True         1
#
#          area_id  is_product_in_segment apteka_name   prefix  new_product_id
# 0            NaN                      1       rigla  1000000         1011076
# 1            NaN                      1       rigla  1000000         1011075
# 2            NaN                      1       rigla  1000000         1011077
# 3            NaN                      1       rigla  1000000         1011078
# 4            NaN                      1       rigla  1000000         1001586
# ...          ...                    ...         ...      ...             ...
# 1708433      NaN                      1      evalar  6000000         6073339
# 1708434      NaN                      1      evalar  6000000         6073340
# 1708435      NaN                      1      evalar  6000000         6073341
# 1708436      NaN                      1      evalar  6000000         6073342
# 1708437      NaN                      1      evalar  6000000         6073343
#
# [1708438 rows x 14 columns]

# %% [markdown]
# В полном списке прдуктов ригла есть

# %%
# Оставим только строки для айдишников из списка отобранных

df_procuct_selected = df_procuct_full[df_procuct_full.new_product_id.isin(new_product_id_selected_list)]
del df_procuct_full

df_procuct_selected = df_procuct_selected.merge(df_procuct_categories_selected[['new_product_id','new_category_id']],
                                               on = 'new_product_id', how = 'left')

df_procuct_selected
# Out:
#       product_id  group_id   price  old_price  manufacturer_id  \
# 0          37908    152693   183.0        NaN            362.0
# 1          69202    153396   412.0        NaN           1387.0
# 2          26779    153449   168.0        NaN            758.0
# 3          12839    164698   246.0        NaN            361.0
# 4          29970    164719   160.0        NaN            602.0
# ...          ...       ...     ...        ...              ...
# 5177       72817     73035  1945.0        NaN             20.0
# 5178       72818     73036   855.0        NaN             20.0
# 5179       72781     73157   539.0        NaN             20.0
# 5180       72787     73184   459.0        NaN             20.0
# 5181       72826     73300   515.0        NaN             20.0
#
#       is_product_unknown  external_system_id  is_available  brand_id  area_id  \
# 0                      0                   5         False         1      NaN
# 1                      0                   5         False         1      NaN
# 2                      0                   5         False         1      NaN
# 3                      0                   5         False         1      NaN
# 4                      0                   5         False         1      NaN
# ...                  ...                 ...           ...       ...      ...
# 5177                   0                   3          True         2      NaN
# 5178                   0                   3          True         2      NaN
# 5179                   0                   3          True         2      NaN
# 5180                   0                   3          True         2      NaN
# 5181                   0                   3          True         2      NaN
#
#       is_product_in_segment apteka_name   prefix  new_product_id  \
# 0                         1    apteka36  3000000         3037908
# 1                         1    apteka36  3000000         3069202
# 2                         1    apteka36  3000000         3026779
# 3                         1    apteka36  3000000         3012839
# 4                         1    apteka36  3000000         3029970
# ...                     ...         ...      ...             ...
# 5177                      1      evalar  6000000         6072817
# 5178                      1      evalar  6000000         6072818
# 5179                      1      evalar  6000000         6072781
# 5180                      1      evalar  6000000         6072787
# 5181                      1      evalar  6000000         6072826
#
#       new_category_id
# 0             3000051
# 1             3000051
# 2             3000051
# 3             3000051
# 4             3000051
# ...               ...
# 5177          6001292
# 5178          6001292
# 5179          6001292
# 5180          6001292
# 5181          6001292
#
# [5182 rows x 15 columns]

# %% [markdown]
# а в отобранном уже нет

# %% [markdown]
# #### сформируем итоговую таблицу с product_infos

# %%
df_procuct_infos_full = make_combined_product_infos()
df_procuct_infos_full
# Out:
# Загрузил:  rigla_product_infos.csv
# Загрузил:  apteka36_product_infos.csv
# Загрузил:  asna_product_infos.csv
# Загрузил:  eapteka_product_infos.csv
# Загрузил:  evalar_product_infos.csv
#        product_id                                               name  \
# 0               1                        Бромокриптин таб. 2,5мг №30
# 1               2     Амфотерицин В лиоф.д/приг.р-ра д/инф. 50000мкг
# 2               3            Амитриптилин р-р д/в/м введ. 1% 2мл №10
# 3               4                               Бутадион мазь 5% 20г
# 4               5                              Вермокс таб. 100мг №6
# ...           ...                                                ...
# 73340       73337  UFEELGOOD Розовая гималайская соль, 200 г, Ufe...
# 73341       73338  Эвалар Витамин D3, 600 МЕ, 60 капсул, Эвалар, ...
# 73342       73339  Levrana Молочко для тела «Арктическая ягода», ...
# 73343       73340  Эвалар Крем для лица, 50 мл, Ци-клим, УЦЕНКА, ...
# 73344       73341  Эвалар Дигидрокверцетин, 60 таблеток, Эвалар, ...
#
#                                                    descr apteka_name   prefix  \
# 0      Нарушения менструального цикла, бесплодие, акр...       rigla  1000000
# 1                             Противогрибковое средство.       rigla  1000000
# 2      Депрессивные состояния, реактивные психозы, ши...       rigla  1000000
# 3      Поверхностные тромбофлебиты нижних конечностей...       rigla  1000000
# 4      Энтеробиоз, трихоцефалез, геогельминтозы, аска...       rigla  1000000
# ...                                                  ...         ...      ...
# 73340  Розовая соль — это природный антисептик. Соль ...      evalar  6000000
# 73341  &lt;p&gt;\r\n     Трудно представить счастливу...      evalar  6000000
# 73342  &lt;p&gt;\r\n     Натуральное молочко для тела...      evalar  6000000
# 73343  &lt;p&gt;\r\n &lt;b&gt;Ци-Клим крем для лица -...      evalar  6000000
# 73344  &lt;p&gt;\r\n &lt;b&gt;Что такое дигидрокверце...      evalar  6000000
#
#        new_product_id
# 0             1000001
# 1             1000002
# 2             1000003
# 3             1000004
# 4             1000005
# ...               ...
# 73340         6073337
# 73341         6073338
# 73342         6073339
# 73343         6073340
# 73344         6073341
#
# [1840730 rows x 6 columns]

# %%
# Оставим только строки для айдишников из списка отобранных

df_procuct_infos_selected = df_procuct_infos_full[df_procuct_infos_full.new_product_id.isin(new_product_id_selected_list)]
# del df_procuct_infos_full

# %%
df_procuct_infos_selected
# Out:
#         product_id                                               name  \
# 176010       12575                                Неизвестный продукт
# 176291       12839                 РиниКолд Хотмикс порошок 5 г 10 шт
# 176448       12997                       Нейролипон капсулы 300мг N30
# 176792       13355                       Bioderma Node шампунь 200 мл
# 177324       13906  Кодали набор питательных уходов для тела 250мл n2
# ...            ...                                                ...
# 73098        72818  Unimat Riken Мармеладки с витаминами, 100 шт, ...
# 73182        72783  Fit-Rx Good Mood, 60 капсул,  Fit-Rx, годен до...
# 73186        72787  SIS Напиток углеводный с электролитами в порош...
# 73301        72825              Калейдоскоп летних новинок Фитомаркет
# 73302        72826  Laboratorium Сыворотка c АНА-кислотами, 50 мл,...
#
#                                                     descr apteka_name  \
# 176010                                                NaN    apteka36
# 176291  <h3>Показания к применению</h3>Комбинированный...    apteka36
# 176448  <h3>Показания к применению</h3>Диабетическая п...    apteka36
# 176792  Шампунь Биодерма Нодэ мягко удаляет загрязнени...    apteka36
# 177324  Набор Caudalie питательный уход для тела (2 ср...    apteka36
# ...                                                   ...         ...
# 73098   Продукт обладает приятным банановым вкусом и с...      evalar
# 73182   &lt;p&gt;\r\n     Работая во взаимодействии, и...      evalar
# 73186   &lt;p&gt;Сбалансированный электролитный напито...      evalar
# 73301                                                 NaN      evalar
# 73302   &lt;p&gt;\r\n    Молочная и гликолевая кислоты...      evalar
#
#          prefix  new_product_id
# 176010  3000000         3012575
# 176291  3000000         3012839
# 176448  3000000         3012997
# 176792  3000000         3013355
# 177324  3000000         3013906
# ...         ...             ...
# 73098   6000000         6072818
# 73182   6000000         6072783
# 73186   6000000         6072787
# 73301   6000000         6072825
# 73302   6000000         6072826
#
# [2155 rows x 6 columns]

# %%
df_procuct_infos_selected.to_csv('procuct_infos_selected.csv')

# %%
df3 = df_procuct_categories_selected.merge(
    df_category_selected[['new_category_id','Name']].rename({'Name':'name_cat'}, axis = 1),
    on = 'new_category_id',
    how = 'left'
)
df3
# Out:
#       product_id  category_id apteka_name   prefix  new_product_id  \
# 0          12575           51    apteka36  3000000         3012575
# 1          12839           51    apteka36  3000000         3012839
# 2          12997           51    apteka36  3000000         3012997
# 3          13355           51    apteka36  3000000         3013355
# 4          13906           51    apteka36  3000000         3013906
# ...          ...          ...         ...      ...             ...
# 2168       72844         1292      evalar  6000000         6072844
# 2169       73205         1292      evalar  6000000         6073205
# 2170       20486         1292      evalar  6000000         6020486
# 2171       20487         1292      evalar  6000000         6020487
# 2172       20491         1292      evalar  6000000         6020491
#
#       new_category_id         name_cat
# 0             3000051  Витамины и БАДы
# 1             3000051  Витамины и БАДы
# 2             3000051  Витамины и БАДы
# 3             3000051  Витамины и БАДы
# 4             3000051  Витамины и БАДы
# ...               ...              ...
# 2168          6001292      БАДы (bady)
# 2169          6001292      БАДы (bady)
# 2170          6001292      БАДы (bady)
# 2171          6001292      БАДы (bady)
# 2172          6001292      БАДы (bady)
#
# [2173 rows x 7 columns]

# %%
df_procuct_infos_selected
# Out:
#         product_id                                               name  \
# 176010       12575                                Неизвестный продукт
# 176291       12839                 РиниКолд Хотмикс порошок 5 г 10 шт
# 176448       12997                       Нейролипон капсулы 300мг N30
# 176792       13355                       Bioderma Node шампунь 200 мл
# 177324       13906  Кодали набор питательных уходов для тела 250мл n2
# ...            ...                                                ...
# 73098        72818  Unimat Riken Мармеладки с витаминами, 100 шт, ...
# 73182        72783  Fit-Rx Good Mood, 60 капсул,  Fit-Rx, годен до...
# 73186        72787  SIS Напиток углеводный с электролитами в порош...
# 73301        72825              Калейдоскоп летних новинок Фитомаркет
# 73302        72826  Laboratorium Сыворотка c АНА-кислотами, 50 мл,...
#
#                                                     descr apteka_name  \
# 176010                                                NaN    apteka36
# 176291  <h3>Показания к применению</h3>Комбинированный...    apteka36
# 176448  <h3>Показания к применению</h3>Диабетическая п...    apteka36
# 176792  Шампунь Биодерма Нодэ мягко удаляет загрязнени...    apteka36
# 177324  Набор Caudalie питательный уход для тела (2 ср...    apteka36
# ...                                                   ...         ...
# 73098   Продукт обладает приятным банановым вкусом и с...      evalar
# 73182   &lt;p&gt;\r\n     Работая во взаимодействии, и...      evalar
# 73186   &lt;p&gt;Сбалансированный электролитный напито...      evalar
# 73301                                                 NaN      evalar
# 73302   &lt;p&gt;\r\n    Молочная и гликолевая кислоты...      evalar
#
#          prefix  new_product_id
# 176010  3000000         3012575
# 176291  3000000         3012839
# 176448  3000000         3012997
# 176792  3000000         3013355
# 177324  3000000         3013906
# ...         ...             ...
# 73098   6000000         6072818
# 73182   6000000         6072783
# 73186   6000000         6072787
# 73301   6000000         6072825
# 73302   6000000         6072826
#
# [2155 rows x 6 columns]

# %%
df3 = df3.merge(df_procuct_infos_selected[['new_product_id', 'name']], on = 'new_product_id' , how = 'left')
df3
# Out:
#       product_id  category_id apteka_name   prefix  new_product_id  \
# 0          12575           51    apteka36  3000000         3012575
# 1          12839           51    apteka36  3000000         3012839
# 2          12997           51    apteka36  3000000         3012997
# 3          13355           51    apteka36  3000000         3013355
# 4          13906           51    apteka36  3000000         3013906
# ...          ...          ...         ...      ...             ...
# 2168       72844         1292      evalar  6000000         6072844
# 2169       73205         1292      evalar  6000000         6073205
# 2170       20486         1292      evalar  6000000         6020486
# 2171       20487         1292      evalar  6000000         6020487
# 2172       20491         1292      evalar  6000000         6020491
#
#       new_category_id         name_cat  \
# 0             3000051  Витамины и БАДы
# 1             3000051  Витамины и БАДы
# 2             3000051  Витамины и БАДы
# 3             3000051  Витамины и БАДы
# 4             3000051  Витамины и БАДы
# ...               ...              ...
# 2168          6001292      БАДы (bady)
# 2169          6001292      БАДы (bady)
# 2170          6001292      БАДы (bady)
# 2171          6001292      БАДы (bady)
# 2172          6001292      БАДы (bady)
#
#                                                    name
# 0                                   Неизвестный продукт
# 1                    РиниКолд Хотмикс порошок 5 г 10 шт
# 2                          Нейролипон капсулы 300мг N30
# 3                          Bioderma Node шампунь 200 мл
# 4     Кодали набор питательных уходов для тела 250мл n2
# ...                                                 ...
# 2168  Эвалар Бэби Формула Мишки Мультивитамины, жева...
# 2169  LIBREDERM Маска себорегулирующая с белой и зел...
# 2170    Эвалар БИО для печени, чай, ф/п по 1,5 г, 20 шт
# 2171                            АнтиГерпес, Помада, 3 г
# 2172  Звездная очанка, капсулы по 0,26 г, 30 шт, бли...
#
# [2173 rows x 8 columns]

# %%
df_procuct_categories_selected[df_procuct_categories_selected.new_category_id == 3000051]
# Out:
#         product_id  category_id apteka_name   prefix  new_product_id  \
# 174316       12575           51    apteka36  3000000         3012575
# 174317       12839           51    apteka36  3000000         3012839
# 174318       12997           51    apteka36  3000000         3012997
# 174319       13355           51    apteka36  3000000         3013355
# 174320       13906           51    apteka36  3000000         3013906
# ...            ...          ...         ...      ...             ...
# 528614       68785           51    apteka36  3000000         3068785
# 528615       69202           51    apteka36  3000000         3069202
# 528616       74129           51    apteka36  3000000         3074129
# 528617       77451           51    apteka36  3000000         3077451
# 528618       77984           51    apteka36  3000000         3077984
#
#         new_category_id
# 174316          3000051
# 174317          3000051
# 174318          3000051
# 174319          3000051
# 174320          3000051
# ...                 ...
# 528614          3000051
# 528615          3000051
# 528616          3000051
# 528617          3000051
# 528618          3000051
#
# [244 rows x 6 columns]

# %% [markdown]
# #### сформируем итоговую таблицу Заказов

# %%
df_purchases_selected = make_combined_purchases(new_product_id_selected_list)
df_purchases_selected
# Out:
# Загрузил:  rigla_purchases.csv
# Загрузил:  apteka36_purchases.csv
# Загрузил:  asna_purchases.csv
# Загрузил:  eapteka_purchases.csv
# Загрузил:  evalar_purchases.csv
#          customer_id  product_id                 datetime  order_id  area_id  \
# 7178          186767       28949  2017-08-25 05:42:00.000      7312      NaN
# 7556          185620       29115  2017-08-25 13:09:56.083      7655      NaN
# 8491         1451512       29523  2017-08-27 10:17:00.000      8445      NaN
# 8575          107011       19839  2017-08-27 14:08:00.000      8544      NaN
# 8742          187507       29650  2017-08-27 20:36:00.000      8706      NaN
# ...              ...         ...                      ...       ...      ...
# 1079841       681072       70941  2021-07-14 13:33:00.000    424837      NaN
# 1079842       681072       70942  2021-07-14 13:33:00.000    424837      NaN
# 1079843       681072       20545  2021-07-14 13:33:00.000    424837      NaN
# 1079878      1546975       20521  2021-07-14 13:56:00.000    424843      NaN
# 1079879      1546975       35644  2021-07-14 13:56:00.000    424843      NaN
#
#         apteka_name   prefix  new_product_id
# 7178       apteka36  3000000         3028949
# 7556       apteka36  3000000         3029115
# 8491       apteka36  3000000         3029523
# 8575       apteka36  3000000         3019839
# 8742       apteka36  3000000         3029650
# ...             ...      ...             ...
# 1079841      evalar  6000000         6070941
# 1079842      evalar  6000000         6070942
# 1079843      evalar  6000000         6020545
# 1079878      evalar  6000000         6020521
# 1079879      evalar  6000000         6035644
#
# [280645 rows x 8 columns]

# %%
df_purchases_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280645 entries, 7178 to 1079879
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   customer_id     280645 non-null  int64
#  1   product_id      280645 non-null  int64
#  2   datetime        280645 non-null  object
#  3   order_id        280645 non-null  int64
#  4   area_id         208422 non-null  float64
#  5   apteka_name     280645 non-null  object
#  6   prefix          280645 non-null  int64
#  7   new_product_id  280645 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 19.3+ MB

# %%
df_procuct_selected
# Out:
#       product_id  group_id   price  old_price  manufacturer_id  \
# 0          37908    152693   183.0        NaN            362.0
# 1          69202    153396   412.0        NaN           1387.0
# 2          26779    153449   168.0        NaN            758.0
# 3          12839    164698   246.0        NaN            361.0
# 4          29970    164719   160.0        NaN            602.0
# ...          ...       ...     ...        ...              ...
# 5177       72817     73035  1945.0        NaN             20.0
# 5178       72818     73036   855.0        NaN             20.0
# 5179       72781     73157   539.0        NaN             20.0
# 5180       72787     73184   459.0        NaN             20.0
# 5181       72826     73300   515.0        NaN             20.0
#
#       is_product_unknown  external_system_id  is_available  brand_id  area_id  \
# 0                      0                   5         False         1      NaN
# 1                      0                   5         False         1      NaN
# 2                      0                   5         False         1      NaN
# 3                      0                   5         False         1      NaN
# 4                      0                   5         False         1      NaN
# ...                  ...                 ...           ...       ...      ...
# 5177                   0                   3          True         2      NaN
# 5178                   0                   3          True         2      NaN
# 5179                   0                   3          True         2      NaN
# 5180                   0                   3          True         2      NaN
# 5181                   0                   3          True         2      NaN
#
#       is_product_in_segment apteka_name   prefix  new_product_id  \
# 0                         1    apteka36  3000000         3037908
# 1                         1    apteka36  3000000         3069202
# 2                         1    apteka36  3000000         3026779
# 3                         1    apteka36  3000000         3012839
# 4                         1    apteka36  3000000         3029970
# ...                     ...         ...      ...             ...
# 5177                      1      evalar  6000000         6072817
# 5178                      1      evalar  6000000         6072818
# 5179                      1      evalar  6000000         6072781
# 5180                      1      evalar  6000000         6072787
# 5181                      1      evalar  6000000         6072826
#
#       new_category_id
# 0             3000051
# 1             3000051
# 2             3000051
# 3             3000051
# 4             3000051
# ...               ...
# 5177          6001292
# 5178          6001292
# 5179          6001292
# 5180          6001292
# 5181          6001292
#
# [5182 rows x 15 columns]

# %%
df_purchases_selected = df_purchases_selected.merge(df_procuct_selected[['new_product_id', 'new_category_id','price']], on = 'new_product_id', how = 'left')


df_purchases_selected
# Out:
#         customer_id  product_id                 datetime  order_id  area_id  \
# 0            186767       28949  2017-08-25 05:42:00.000      7312      NaN
# 1            186767       28949  2017-08-25 05:42:00.000      7312      NaN
# 2            186767       28949  2017-08-25 05:42:00.000      7312      NaN
# 3            186767       28949  2017-08-25 05:42:00.000      7312      NaN
# 4            186767       28949  2017-08-25 05:42:00.000      7312      NaN
# ...             ...         ...                      ...       ...      ...
# 936952       681072       70942  2021-07-14 13:33:00.000    424837      NaN
# 936953       681072       70942  2021-07-14 13:33:00.000    424837      NaN
# 936954       681072       20545  2021-07-14 13:33:00.000    424837      NaN
# 936955      1546975       20521  2021-07-14 13:56:00.000    424843      NaN
# 936956      1546975       35644  2021-07-14 13:56:00.000    424843      NaN
#
#        apteka_name   prefix  new_product_id  new_category_id   price
# 0         apteka36  3000000         3028949          3000051    74.0
# 1         apteka36  3000000         3028949          3000051    74.0
# 2         apteka36  3000000         3028949          3000051    74.0
# 3         apteka36  3000000         3028949          3000051    74.0
# 4         apteka36  3000000         3028949          3000051    74.0
# ...            ...      ...             ...              ...     ...
# 936952      evalar  6000000         6070942          6001191  2190.0
# 936953      evalar  6000000         6070942          6001292  2190.0
# 936954      evalar  6000000         6020545          6001292   515.0
# 936955      evalar  6000000         6020521          6001292  1131.0
# 936956      evalar  6000000         6035644          6001292   165.0
#
# [936957 rows x 10 columns]

# %%
df_purchases_selected['datetime'] = pd.to_datetime(df_purchases_selected['datetime'] )

# %%
df_purchases_selected['year'] = df_purchases_selected['datetime'].dt.year
df_purchases_selected['month'] = df_purchases_selected['datetime'].dt.month
df_purchases_selected['day'] = df_purchases_selected['datetime'].dt.day

df_purchases_selected = df_purchases_selected.set_index('datetime')

df_purchases_selected
# Out:
#                      customer_id  product_id  order_id  area_id apteka_name  \
# datetime
# 2017-08-25 05:42:00       186767       28949      7312      NaN    apteka36
# 2017-08-25 05:42:00       186767       28949      7312      NaN    apteka36
# 2017-08-25 05:42:00       186767       28949      7312      NaN    apteka36
# 2017-08-25 05:42:00       186767       28949      7312      NaN    apteka36
# 2017-08-25 05:42:00       186767       28949      7312      NaN    apteka36
# ...                          ...         ...       ...      ...         ...
# 2021-07-14 13:33:00       681072       70942    424837      NaN      evalar
# 2021-07-14 13:33:00       681072       70942    424837      NaN      evalar
# 2021-07-14 13:33:00       681072       20545    424837      NaN      evalar
# 2021-07-14 13:56:00      1546975       20521    424843      NaN      evalar
# 2021-07-14 13:56:00      1546975       35644    424843      NaN      evalar
#
#                       prefix  new_product_id  new_category_id   price  year  \
# datetime
# 2017-08-25 05:42:00  3000000         3028949          3000051    74.0  2017
# 2017-08-25 05:42:00  3000000         3028949          3000051    74.0  2017
# 2017-08-25 05:42:00  3000000         3028949          3000051    74.0  2017
# 2017-08-25 05:42:00  3000000         3028949          3000051    74.0  2017
# 2017-08-25 05:42:00  3000000         3028949          3000051    74.0  2017
# ...                      ...             ...              ...     ...   ...
# 2021-07-14 13:33:00  6000000         6070942          6001191  2190.0  2021
# 2021-07-14 13:33:00  6000000         6070942          6001292  2190.0  2021
# 2021-07-14 13:33:00  6000000         6020545          6001292   515.0  2021
# 2021-07-14 13:56:00  6000000         6020521          6001292  1131.0  2021
# 2021-07-14 13:56:00  6000000         6035644          6001292   165.0  2021
#
#                      month  day
# datetime
# 2017-08-25 05:42:00      8   25
# 2017-08-25 05:42:00      8   25
# 2017-08-25 05:42:00      8   25
# 2017-08-25 05:42:00      8   25
# 2017-08-25 05:42:00      8   25
# ...                    ...  ...
# 2021-07-14 13:33:00      7   14
# 2021-07-14 13:33:00      7   14
# 2021-07-14 13:33:00      7   14
# 2021-07-14 13:56:00      7   14
# 2021-07-14 13:56:00      7   14
#
# [936957 rows x 12 columns]

# %% [markdown]
# ## Расчитаем динамику по объемам и ТОП 15 продаж

# %%
df1 = df_purchases_selected.groupby([df_purchases_selected.index.year, df_purchases_selected.index.month]).sum()[['price']]
# df1

# %%
# График типовыми средствами matplotlib

ax = df1.plot(style = '*-')
ax.set_title('Динамика объемов продаж всего')
ax.set_xlabel('Год \ месяц');
ax.set_ylabel('Цена * штук заказов');

# %% [markdown]
# #### ТОП 15 по объемам продаж по аптеке

# %%
# Сгруппируем по product_id, осортируем по убыванию и оставим ТОП 25
for apteka, data in df_purchases_selected.groupby(df_purchases_selected.apteka_name):
    df2 = data.groupby([data.new_product_id], as_index = True)[[ 'price']].sum().sort_values(by = 'price', ascending = False).head(15)
    df2 = df2.sort_values(by = 'price', ascending = True)
    df2 = df2.merge(df_procuct_infos_selected[['new_product_id','name']], on = 'new_product_id', how = 'left')
    fig, ax = plt.subplots()    
    ax.barh(df2.index, df2.price)

    ax.set_title('TOП 15 продуктов за весь период продаж '+ apteka)
    ax.set_ylabel('Продукт');
    ax.set_xlabel('Цена * штук заказов');

    #  Устанавливаем позиции тиков:
    ax.set_yticks(df2.index)

    #  Устанавливаем подписи тиков
    ax.set_yticklabels(df2.name)
    plt.show()

# %% [markdown]
# ## Обработаем сравнение по периодам

# %%
df_purchases_selected.sort_index(inplace = True)

# %%
df_purchases_selected.head()
# Out:
#                      customer_id  product_id  order_id  area_id apteka_name  \
# datetime
# 2017-04-04 16:12:14       182252        1630    121821      NaN        asna
# 2017-04-04 16:12:14       182252        1630    121821      NaN        asna
# 2017-04-12 09:12:22       192762        6883    125453      NaN        asna
# 2017-04-13 09:14:00       182716       10926     97255      NaN        asna
# 2017-04-13 09:14:06       486632        3487    126708      NaN        asna
#
#                       prefix  new_product_id  new_category_id   price  year  \
# datetime
# 2017-04-04 16:12:14  4000000         4001630          4002983   444.0  2017
# 2017-04-04 16:12:14  4000000         4001630          4002983   444.0  2017
# 2017-04-12 09:12:22  4000000         4006883          4002983  1399.0  2017
# 2017-04-13 09:14:00  4000000         4010926          4002983   387.0  2017
# 2017-04-13 09:14:06  4000000         4003487          4002983   227.0  2017
#
#                      month  day
# datetime
# 2017-04-04 16:12:14      4    4
# 2017-04-04 16:12:14      4    4
# 2017-04-12 09:12:22      4   12
# 2017-04-13 09:14:00      4   13
# 2017-04-13 09:14:06      4   13

# %%
df1 = df_purchases_selected['2020-07-01':'2020-12-31'][['apteka_name', 'new_product_id', 'price']]
df1 = df1.groupby(['apteka_name', 'new_product_id']).sum()
df1 = df1.rename({'price':'2020_2'}, axis = 1)
df1
# Out:
#                              2020_2
# apteka_name new_product_id
# apteka36    3012575         93568.0
#             3018663          2256.0
#             3018937         12024.0
#             3019765         74736.0
#             3020139          9440.0
# ...                             ...
# evalar      6066616          2575.0
#             6066617         33912.0
#             6066618         75810.0
#             6067515          6282.0
#             6067751          3832.0
#
# [649 rows x 1 columns]

# %%
df2 = df_purchases_selected['2021-01-01':'2021-06-30'][['apteka_name', 'new_product_id', 'price']]
df2 = df2.groupby(['apteka_name', 'new_product_id']).sum()
df2 = df2.rename({'price':'2021_1'}, axis = 1)
df2
# Out:
#                              2021_1
# apteka_name new_product_id
# apteka36    3012575         16512.0
#             3019765          8304.0
#             3019839          2720.0
#             3023968          7928.0
#             3024899         12600.0
# ...                             ...
# evalar      6071014         19250.0
#             6071015           789.0
#             6071773          2245.0
#             6072011          2260.0
#             6072787          3213.0
#
# [824 rows x 1 columns]

# %%
# сольем 2 полугодия в одну таблицу
df3 = df2.merge(df1, left_index=True, right_index=True, how = 'left')

# %%
# Отсутсвие продаж заполным малым занчением, чтобы не было деления на 0. 
df3.fillna(0.1, inplace = True)

# Вернемся к простому индексу, аптека и продукт перейдут в колонки
df3.reset_index(inplace = True)

# %%
# Прирост %
df3['k'] = ((df3['2021_1'] - df3['2020_2']) / df3['2020_2'] * 100).round(1)

# Суммовое изменение
df3['delta'] = df3['2021_1'] - df3['2020_2']

# %%
df3.sort_values(by = 'k', ascending = False).head()
# Out:
#     apteka_name  new_product_id    2021_1  2020_2            k     delta
# 471     eapteka         5225770  359040.0     0.1  359039900.0  359039.9
# 483     eapteka         5227275  125421.0     0.1  125420900.0  125420.9
# 442     eapteka         5225317  120080.0     0.1  120079900.0  120079.9
# 816      evalar         6070942  100740.0     0.1  100739900.0  100739.9
# 411     eapteka         5161272   90132.0     0.1   90131900.0   90131.9

# %% [markdown]
# #### ТОП 15 по проценту прироста 2021_1 к 2020_2

# %%
# Сгруппируем по product_id, осортируем по убыванию и оставим ТОП 25
for apteka, data in df3.groupby(df3.apteka_name):
    df2 = data.groupby([data.new_product_id], as_index = True)[['k']].sum().sort_values(by = 'k', ascending = False).head(15)
    df2 = df2.sort_values(by = 'k', ascending = True)
    # Подгрузим названия 
    df2 = df2.merge(df_procuct_infos_selected[['new_product_id','name']], on = 'new_product_id', how = 'left')
    fig, ax = plt.subplots()    
    ax.barh(df2.index, df2.k)

    ax.set_title('TOП 15 по проценту прироста, '+ apteka)
    ax.set_ylabel('Продукт');
    ax.set_xlabel('Процент прироста');

    #  Устанавливаем позиции тиков:
    ax.set_yticks(df2.index)

    #  Устанавливаем подписи тиков
    ax.set_yticklabels(df2.name)
    plt.show()

# %% [markdown]
# #### ТОП 15 по суммовому приросту 2021_1 к 2020_2

# %%
# Сгруппируем по product_id, осортируем по убыванию и оставим ТОП 25
for apteka, data in df3.groupby(df3.apteka_name):
    df2 = data.groupby([data.new_product_id], as_index = True)[['delta']].sum().sort_values(by = 'delta', ascending = False).head(15)
    df2 = df2.sort_values(by = 'delta', ascending = True)
    # Подгрузим названия 
    df2 = df2.merge(df_procuct_infos_selected[['new_product_id','name']], on = 'new_product_id', how = 'left')
    fig, ax = plt.subplots()    
    ax.barh(df2.index, df2.delta)

    ax.set_title('TOП 15 по суммовому приросту, '+ apteka)
    ax.set_ylabel('Продукт');
    ax.set_xlabel('Сумма прироста');

    #  Устанавливаем позиции тиков:
    ax.set_yticks(df2.index)

    #  Устанавливаем подписи тиков
    ax.set_yticklabels(df2.name)
    plt.show()
